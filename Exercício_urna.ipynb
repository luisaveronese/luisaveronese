# %% [markdown]
# <a href="https://colab.research.google.com/github/luisaveronese/luisaveronese/blob/main/Exerc%C3%ADcio_urna.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Trabalho Urna
#Aluna: Luísa Moraes
#RA: 1934857
#Curso: Análise e desenvolvimento de sistemas
#Disciplina: Construção de algoritmos
#Semestre: 1


eleitores = int(input("digite o número total de eleitores: "))
candiA = 0
candiB = 0
candiC = 0
votantes = 1
valido = 0
tentativa = 0
while (votantes <= eleitores):
  voto = int(input("Digite 1 para votar em Vincent Vega, 2 para votar em Jules Winnfield e 3 para votar em Marsellus Wallace: "))
  if(voto == 1):
    candiA = candiA + 1
    print("Seu voto foi validado, obrigado!")
    votantes = votantes + 1
  elif(voto == 2):
    candiB = candiB + 1
    print("Seu voto foi validado, obrigado!")
    votantes = votantes + 1
  elif(voto == 3):
    candiC = candiC + 1  
    print("Seu voto foi validado, obrigado!")
    votantes = votantes + 1
  
  elif(voto > 3 and tentativa >= 5):
    print("Voto inválido, por favor, tente novamente.")
    tentativa = tentativa + 1
    valido != 0
    votantes = votantes + 0
  elif(tentativa == 6):
    print("voto anulado.")
    votantes = votantes - 1  
  while (votantes > eleitores):
      break

votos = candiA + candiB + candiC
porcentA = votos / 100
porcentB = votos / 100
porcentC = votos / 100 
if candiA == candiB:
  print(f"Houve um empate entre Vincent Vega e Jules Winnfield de {porcentA + porcentB}%. ")
elif candiB == candiC:
  print(f"Houve um empate entre Jules Winnfield e Marsellus Wallace de {porcentB + porcentC}%. ")
elif candiC == candiA:
  print(f"Houve um empate entre Vincent Vega e Marsellus Wallace de {porcentA + porcentC}%. ")



print(f"Vincent Vega teve {candiA} voto(s);")
print(f"Jules Winnfield teve {candiB} voto(s);")
print(f"Marsellus Wallace teve {candiC} voto(s).")

# %%
#Trabalho Urna
#Aluna: Luísa Moraes
#RA: 1934857
#Curso: Análise e desenvolvimento de sistemas
#Disciplina: Construção de algoritmos
#Semestre: 1


eleitores = int(input("digite o número total de eleitores: "))
candiA = 0
candiB = 0
candiC = 0
votantes = 1
valido = 0
tentativa = 0
while (votantes <= eleitores):
  voto = int(input("Digite 1 para votar em Vincent Vega, 2 para votar em Jules Winnfield e 3 para votar em Marsellus Wallace: "))
  if(voto == 1):
    candiA = candiA + 1
    print("Seu voto foi validado, obrigado!")
  elif(voto == 2):
    candiB = candiB + 1
    print("Seu voto foi validado, obrigado!")
  elif(voto == 3):
    candiC = candiC + 1  
    print("Seu voto foi validado, obrigado!")
  elif(voto > 3 and tentativa <= 5):
    print("Voto inválido, por favor, tente novamente.")
    tentativa = tentativa + 1
    valido != 0
    voto = int(input("Digite 1 para votar em Vincent Vega, 2 para votar em Jules Winnfield e 3 para votar em Marsellus Wallace: "))
  elif(tentativa > 5):
    print("voto anulado.")  
  votantes = votantes + 1
  while (votantes > eleitores):
      break


porcentA = candiA / 100
porcentB = candiB / 100
porcentC = candiC / 100 
if candiA == candiB:
  print(f"Houve um empate entre Vincent Vega e Jules Winnfield de {porcentA + porcentB}%. ")
elif candiB == candiC:
  print(f"Houve um empate entre Jules Winnfield e Marsellus Wallace de {porcentB + porcentC}%. ")
elif candiC == candiA:
  print(f"Houve um empate entre Vincent Vega e Marsellus Wallace de {porcentA + porcentC}%. ")



print(f"Vincent Vega teve {candiA} voto(s);")
print(f"Jules Winnfield teve {candiB} voto(s);")
print(f"Marsellus Wallace teve {candiC} voto(s).")
